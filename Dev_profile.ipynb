# %% [markdown]
# ## Dev profile as variables

# %%
name = "Hrishabh Singh Tomar"
age = 25
city = "Rochester, Ny"
college = "Simon Business School"
current_topic = "Oops"
experience = 4
like_python = True
expected_salary = 80000
gpa = 3.8  # float — added to cover the float type

# Printing every value
print("Name:", name)
print("Age:", age)
print("City:", city)
print("College/Company:", college)
print("Current Learning Topic:", current_topic)
print("Years of Experience/Study:", experience)
print("Likes Python:", like_python)
print("Expected Salary after learning Python:", expected_salary)
print("GPA:", gpa)

print("\n--- Data Types ---")
print("Type of name:", type(name))
print("Type of age:", type(age))
print("Type of city:", type(city))
print("Type of college_or_company:", type(college))
print("Type of current_topic:", type(current_topic))
print("Type of years_of_experience:", type(experience))
print("Type of likes_python:", type(like_python))
print("Type of expected_salary:", type(expected_salary))
print("Type of gpa:", type(gpa))
# Out:
# Name: Hrishabh Singh Tomar
# Age: 25
# City: Rochester, Ny
# College/Company: Simon Business School
# Current Learning Topic: Oops
# Years of Experience/Study: 4
# Likes Python: True
# Expected Salary after learning Python: 80000
# GPA: 3.8
#
# --- Data Types ---
# Type of name: <class 'str'>
# Type of age: <class 'int'>
# Type of city: <class 'str'>
# Type of college_or_company: <class 'str'>
# Type of current_topic: <class 'str'>
# Type of years_of_experience: <class 'int'>
# Type of likes_python: <class 'bool'>
# Type of expected_salary: <class 'int'>
# Type of gpa: <class 'float'>
